# %% [markdown]
# <a href="https://colab.research.google.com/github/Feev004/Colab_Big_Data_Technologies/blob/main/Chapter_1_2_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **pandas**
#
# ย่อมาจากคำว่า “panel data”
#
# https://pypi.org/project/pandas/
#
# ความสามารถของตัว pandas จัดการข้อมูลที่อยู่รูปแบบ tabular หรือในรูปแบบตาราง
#
# pandas เป็น library ที่เสริมความสามารถของ numpy ให้มากขึ้น
#
# เราได้เข้าใจพื้นฐานของ array มาจาก numpy มาแล้ว
#
# pandas อาจจะยังไม่ถูกติดตั้งมาพร้อม Python ดังนั้นจำเป็นจะต้องติดตั้งลงเครื่องก่อน เช่น
# ```
# pip install pandas
# ```

# %% [markdown]
# import numpy as np
#
# import pandas as pd

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##Series และ DataFrame
#
# Series (1D) - labeled, homogenous array of immutable size
#
# DataFrames (2D) - labeled, heterogeneously typed, size-mutable tabular data structures
#
# Series และ DataFrame เป็นเหมือนที่บรรจุข้อมูลเพื่อนำมาวิเคราะห์ในงาน data science
#
# Series หรือ อนุกรม คือชุดข้อมูลที่เรียงต่อกัน และเราจะอาศัยพื้นฐานความสามารถของ numpy
#
# DataFrame คือตารางของข้อมูล ซึ่งประกอบขึ้นจากหลาย ๆ Series
#
# ต่อไปเราจะใช้ประโยชน์จาก DataFrame

# %% [markdown]
# ###Creating a Series

# %% [markdown]
# **Creating an empty Series**

# %%
myseries = pd.Series() # The Series() function creates a new Series
print(myseries)
type(myseries)
# Out:
# Series([], dtype: object)
# pandas.core.series.Series

# %%
myseries1 = pd.Series(['สุดา','กันยา','สมพร','Ann','Pimpa'])
print(myseries1)
print(pd.Series([1,2,9,3])) #print ซีรีส์ออกมาจะอยู่ในรูปที่ดูเป็นระเบียบดูง่าย
# Out:
# 0     สุดา
# 1    กันยา
# 2     สมพร
# 3      Ann
# 4    Pimpa
# dtype: object
# 0    1
# 1    2
# 2    9
# 3    3
# dtype: int64

# %% [markdown]
# dtype คือชนิดของข้อมูล เช่นเดียวกับในอาเรย์ของ numpy
#
# ชนิดข้อมูลสามารถระบุได้ตอนสร้างโดยเพิ่มคีย์เวิร์ด dtype

# %%
print(pd.Series([1,2,'9',3.1],dtype='float64')) # หรือ dtype=float
# Out:
# 0    1.0
# 1    2.0
# 2    9.0
# 3    3.1
# dtype: float64

# %% [markdown]
# **Creating a series from an ndarray**

# %%
# Note that indexes are a assigned automatically if not specifies
arr = np.array([10,20,30,40,50])
series1 = pd.Series(arr)
print(series1)
print(series1.index)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# **Creating a series from a Python dict**

# %%
# Note that the keys of the dictionary are used to assign indexes during conversion
data = {'a':10, 'b':20, 'c':30}
series2 = pd.Series(data)
print(series2)
print(series2.index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
# Index(['a', 'b', 'c'], dtype='object')

# %% [markdown]
# index เป็นได้ทั้งตัวเลข หรือตัวอักษร

# %% [markdown]
# ###**Retrieving a part of the series**

# %%
print(series1[1:4])
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# ข้อมูลภายในสามารถเข้าถึงได้โดยอาศัยดัชนีซึ่งอยู่ทางซ้าย
#
# เช่น

# %% [markdown]
# ###การวิเคราะห์ข้อมูลใน Series

# %%
stu = pd.Series(
    [15.0,19.9,54.4,10.8,12.43,19.15],
    index=['หมูน้อย','มานพ','สุดา','สิทธา','สามจอม','วันดี']
)
print(stu.sum())
print(stu.mean())
print(stu.max())
print(stu.argmax())
print(stu.min())
print(stu.argmin())
print(stu.std())
print(stu)
# Out:
# 131.68
# 21.94666666666667
# 54.4
# 2
# 10.8
# 3
# 16.299081773727828
# หมูน้อย    15.00
# มานพ       19.90
# สุดา       54.40
# สิทธา      10.80
# สามจอม     12.43
# วันดี      19.15
# dtype: float64

# %% [markdown]
# ###การเพิ่มและแก้ไขข้อมูล

# %%
stu['มิตติ'] = 31.8 #การเพิ่ม
stu['พาวา'] = 23.57 #การเพิ่ม
stu['หมูน้อย'] = 30 #แก้ไขข้อมูล
print(stu)
# Out:
# หมูน้อย    30.00
# มานพ       19.90
# สุดา       54.40
# สิทธา      10.80
# สามจอม     12.43
# วันดี      19.15
# มิตติ      31.80
# พาวา       23.57
# dtype: float64

# %% [markdown]
# Series เป็นแค่แถวของข้อมูลซึ่งมีเพียงมิติเดียว
#
# ถ้าเรามีข้อมูลหลายชุด จำเป็นจะต้องสร้าง Series หลายอัน
#
# Series หลายอันจะมารวมเข้าเป็นตาราง
#
# ตารางข้อมูลที่เกิดจากการรวมนั้นก็คือ DataFrames
#
# Series อาจเทียบได้กับ array 1 มิติ
#
# DataFrames อาจเทียบได้กับ array 2 มิติ

# %% [markdown]
# ##**DataFrames**
# 1. A DataFrame is a 2D data structure in which data is aligned in a tabular fashion consisting of rows & columns
# 2. A DataFrame can be created using the following constructor - pandas.DataFrame(data, index, dtype, copy)
# 3. Data can be of multiple data types such as ndarray, list, constants, series, dict etc.
# 4. Index Row and column labels of the dataframe; defaults to np.arrange(n) if no index is passed
# 5. Data type of each column
# 6. Creates a deep copy of the data, set to false as default

# %% [markdown]
# ###**Creating a DataFrame**
#
# DataFrame สามารถถูกสร้างขึ้นได้โดยใช้
# ```
# pd.DataFrame()
# ```
# วิธีการสร้างนั้นมีหลายวิธี

# %% [markdown]
# **Converting a list into a DataFrame**

# %%
list1 = [10, 20, 30, 40]
print(list1[0])
print(list1[2])
table = pd.DataFrame(list1)
print(table)
# Out:
# 10
# 30
#     0
# 0  10
# 1  20
# 2  30
# 3  40

# %% [markdown]
# ตัวอย่าง สร้างตารางข้อมูลของนักเรียน ซึ่งข้อมูลประกอบไปด้วยชื่อ, เพศ, ส่วนสูง และน้ำหนัก ข้อมูลแต่ละอย่างใส่ในคนละคอลัมน์ และหนึ่งแถวคือนักเรียนหนึ่งคน

# %%
s = [['สุดา','ญ',150,64],
     ['มานพ','ช',160,55],
     ['ยานี','ญ',157,65]]
print(s[0])
print(s[2])
stu = pd.DataFrame(s)
print(stu)
# Out:
# ['สุดา', 'ญ', 150, 64]
# ['ยานี', 'ญ', 157, 65]
#       0  1    2   3
# 0  สุดา  ญ  150  64
# 1  มานพ  ช  160  55
# 2  ยานี  ญ  157  65

# %%
# The append() function can be used to add more rows to the DataFrame
data2 = {'one':pd.Series([1,2,3], index = ['a', 'b', 'c']),
        'two':pd.Series([1,2,3,4], index = ['a', 'b', 'c', 'd'])}
table5 = pd.DataFrame(data2)
print(table5)
table5['three'] = pd.Series([10,20,30], index = ['a', 'b', 'c'])
row = pd.DataFrame([[11,13],[17,19]], columns = ['two', 'three'])

table6 = pd.concat([table5, row], ignore_index=True)
table6
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
#    one  two  three
# 0  1.0    1   10.0
# 1  2.0    2   20.0
# 2  3.0    3   30.0
# 3  NaN    4    NaN
# 4  NaN   11   13.0
# 5  NaN   17   19.0

# %%
# The drop() function can be used to drop rows whose labels are provided
table7 = table6.drop(0)
table7
# Out:
#    one  two  three
# 1  2.0    2   20.0
# 2  3.0    3   30.0
# 3  NaN    4    NaN
# 4  NaN   11   13.0
# 5  NaN   17   19.0

# %%
table7 = table6.drop(['three'], axis=1)
table7
# Out:
#    one  two
# 0  1.0    1
# 1  2.0    2
# 2  3.0    3
# 3  NaN    4
# 4  NaN   11
# 5  NaN   17

# %% [markdown]
# ##แบบฝึกหัด WS#2.1
# ขอให้นักศึกษานำข้อมูลจาก Wine dataset มาทำการคำนวณค่าทาง statistics
# โดยแสดงค่าต่อไปนี้
# ค่า sum
# ค่า mean
# ค่า max
# ค่า sd
# ของแต่ละแอททริบิวต์ และแสดงผลลัพธ์ออกมาทางจอภาพ

# %%
from google.colab import drive
drive.mount('/content/drive') #ระวังเครื่องหมาย ‘ กับ ' ต่างกันนะคะ
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
path = '/content/drive/MyDrive/Colab Notebooks/wine_data.csv'
myfiledata = pd.read_csv(path) ## Dataset is now stored in a Pandas Dataframe
myfiledata
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# 3    2.93   735
# 4    2.85  1450
# ..    ...   ...
# 172  1.74   740
# 173  1.56   750
# 174  1.56   835
# 175  1.62   840
# 176  1.60   560
#
# [177 rows x 14 columns]

# %%
features = ["Cultivator", "Alchol", "Malic_Acid", "Ash", "Alcalinity_of_Ash", "Magnesium", "Total_phenols", "Falvanoids", "Nonflavanoid_phenols", "Proanthocyanins", "Color_intensity", "Hue", "OD280", "Proline"]
winedata = pd.read_csv(path, names = features) #ถ้าอ่านจาก drive ให้ใช้ ตัวแปร path
#winedata = pd.read_csv('wine_data.csv', names = features) #้ถ้าอ่านจาก local ให้ระบุชื่อไฟล์ได้เลย
winedata.tail(10)
# Out:
#      Cultivator  Alchol  Malic_Acid   Ash  Alcalinity_of_Ash  Magnesium  \
# 168           3   13.58        2.58  2.69               24.5        105
# 169           3   13.40        4.60  2.86               25.0        112
# 170           3   12.20        3.03  2.32               19.0         96
# 171           3   12.77        2.39  2.28               19.5         86
# 172           3   14.16        2.51  2.48               20.0         91
# 173           3   13.71        5.65  2.45               20.5         95
# 174           3   13.40        3.91  2.48               23.0        102
# 175           3   13.27        4.28  2.26               20.0        120
# 176           3   13.17        2.59  2.37               20.0        120
# 177           3   14.13        4.10  2.74               24.5         96
#
#      Total_phenols  Falvanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 168           1.55        0.84                  0.39             1.54
# 169           1.98        0.96                  0.27             1.11
# 170           1.25        0.49                  0.40             0.73
# 171           1.39        0.51                  0.48             0.64
# 172           1.68        0.70                  0.44             1.24
# 173           1.68        0.61                  0.52             1.06
# 174           1.80        0.75                  0.43             1.41
# 175           1.59        0.69                  0.43             1.35
# 176           1.65        0.68                  0.53             1.46
# 177           2.05        0.76                  0.56             1.35
#
#      Color_intensity   Hue  OD280  Proline
# 168         8.660000  0.74   1.80      750
# 169         8.500000  0.67   1.92      630
# 170         5.500000  0.66   1.83      510
# 171         9.899999  0.57   1.63      470
# 172         9.700000  0.62   1.71      660
# 173         7.700000  0.64   1.74      740
# 174         7.300000  0.70   1.56      750
# 175        10.200000  0.59   1.56      835
# 176         9.300000  0.60   1.62      840
# 177         9.200000  0.61   1.60      560

# %%
winedata = winedata.drop(['Cultivator'], axis=1)
winedata
# Out:
#      Alchol  Malic_Acid   Ash  Alcalinity_of_Ash  Magnesium  Total_phenols  \
# 0     14.23        1.71  2.43               15.6        127           2.80
# 1     13.20        1.78  2.14               11.2        100           2.65
# 2     13.16        2.36  2.67               18.6        101           2.80
# 3     14.37        1.95  2.50               16.8        113           3.85
# 4     13.24        2.59  2.87               21.0        118           2.80
# ..      ...         ...   ...                ...        ...            ...
# 173   13.71        5.65  2.45               20.5         95           1.68
# 174   13.40        3.91  2.48               23.0        102           1.80
# 175   13.27        4.28  2.26               20.0        120           1.59
# 176   13.17        2.59  2.37               20.0        120           1.65
# 177   14.13        4.10  2.74               24.5         96           2.05
#
#      Falvanoids  Nonflavanoid_phenols  Proanthocyanins  Color_intensity   Hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      OD280  Proline
# 0     3.92     1065
# 1     3.40     1050
# 2     3.17     1185
# 3     3.45     1480
# 4     2.93      735
# ..     ...      ...
# 173   1.74      740
# 174   1.56      750
# 175   1.56      835
# 176   1.62      840
# 177   1.60      560
#
# [178 rows x 13 columns]

# %% [markdown]
# **แบบฝึกหัด**
#
# จงหาค่า sum ค่า mean ค่า max ค่า sd ของแต่ละแอททริบิวต์ และแสดงผลลัพธ์ออกมาทางจอภาพ
#
# ตัวอย่างค่า sum
#
# Alchol                    2314.110000
#
# Malic_Acid                 415.870000
#
# Ash                        421.240000
#
# Alcalinity_of_Ash         3470.100000
#
# Magnesium                17754.000000
#
# Total_phenols              408.530000
#
# Falvanoids                 361.210000
#
# Nonflavanoid_phenols        64.410000
#
# Proanthocyanins            283.180000
#
# Color_intensity            900.339999
#
# Hue                        170.426000
#
# OD280                      464.880000
#
# Proline                 132947.000000
#
# dtype: float64

# %%
 # เขียน code ตรงนี้
print(winedata.sum())
print(winedata.mean())
print(winedata.max())
print(winedata.min())
# Out:
# Alchol                    2314.110000
# Malic_Acid                 415.870000
# Ash                        421.240000
# Alcalinity_of_Ash         3470.100000
# Magnesium                17754.000000
# Total_phenols              408.530000
# Falvanoids                 361.210000
# Nonflavanoid_phenols        64.410000
# Proanthocyanins            283.180000
# Color_intensity            900.339999
# Hue                        170.426000
# OD280                      464.880000
# Proline                 132947.000000
# dtype: float64
# Alchol                   13.000618
# Malic_Acid                2.336348
# Ash                       2.366517
# Alcalinity_of_Ash        19.494944
# Magnesium                99.741573
# Total_phenols             2.295112
# Falvanoids                2.029270
# Nonflavanoid_phenols      0.361854
# Proanthocyanins           1.590899
# Color_intensity           5.058090
# Hue                       0.957449
# OD280                     2.611685
# Proline                 746.893258
# dtype: float64
# Alchol                    14.83
# Malic_Acid                 5.80
# Ash                        3.23
# Alcalinity_of_Ash         30.00
# Magnesium                162.00
# Total_phenols              3.88
# Falvanoids                 5.08
# Nonflavanoid_phenols       0.66
# Proanthocyanins            3.58
# Color_intensity           13.00
# Hue                        1.71
# OD280                      4.00
# Proline                 1680.00
# dtype: float64
# Alchol                   11.03
# Malic_Acid                0.74
# Ash                       1.36
# Alcalinity_of_Ash        10.60
# Magnesium                70.00
# Total_phenols             0.98
# Falvanoids                0.34
# Nonflavanoid_phenols      0.13
# Proanthocyanins           0.41
# Color_intensity           1.28
# Hue                       0.48
# OD280                     1.27
# Proline                 278.00
# dtype: float64

# %% [markdown]
# **จงแปลงผลลัพธ์ที่ได้ให้อยู่ในรูปแบบ DataFrame**

# %%
#เขียน code ต่อจากตรงนี้
result = {'Sum' : winedata.sum(),
          'Min' : winedata.min(),
          'Max' : winedata.max(),
          'Std' : winedata.std(),
          }

ds = pd.DataFrame(result)
ds
# Out:
#                                 Sum     Min      Max         Std
# Alchol                  2314.110000   11.03    14.83    0.811827
# Malic_Acid               415.870000    0.74     5.80    1.117146
# Ash                      421.240000    1.36     3.23    0.274344
# Alcalinity_of_Ash       3470.100000   10.60    30.00    3.339564
# Magnesium              17754.000000   70.00   162.00   14.282484
# Total_phenols            408.530000    0.98     3.88    0.625851
# Falvanoids               361.210000    0.34     5.08    0.998859
# Nonflavanoid_phenols      64.410000    0.13     0.66    0.124453
# Proanthocyanins          283.180000    0.41     3.58    0.572359
# Color_intensity          900.339999    1.28    13.00    2.318286
# Hue                      170.426000    0.48     1.71    0.228572
# OD280                    464.880000    1.27     4.00    0.709990
# Proline               132947.000000  278.00  1680.00  314.907474

# %%
#ตัวอย่างผลลัพธ์
# Out:
#                                 Sum     Min      Max         Std
# Alchol                  2314.110000   11.03    14.83    0.811827
# Malic_Acid               415.870000    0.74     5.80    1.117146
# Ash                      421.240000    1.36     3.23    0.274344
# Alcalinity_of_Ash       3470.100000   10.60    30.00    3.339564
# Magnesium              17754.000000   70.00   162.00   14.282484
# Total_phenols            408.530000    0.98     3.88    0.625851
# Falvanoids               361.210000    0.34     5.08    0.998859
# Nonflavanoid_phenols      64.410000    0.13     0.66    0.124453
# Proanthocyanins          283.180000    0.41     3.58    0.572359
# Color_intensity          900.339999    1.28    13.00    2.318286
# Hue                      170.426000    0.48     1.71    0.228572
# OD280                    464.880000    1.27     4.00    0.709990
# Proline               132947.000000  278.00  1680.00  314.907474

# %% [markdown]
# # แบบฝึกหัด DataFrame ชุดข้อมูล Sport Car Price

# %% [markdown]
# 1. Copy file to "csv" folder then mount drive
# This dataset download from [kaggle](https://www.kaggle.com/datasets/rkiattisak/sports-car-prices-dataset?resource=download)

# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')

# Path to the CSV file in your Google Drive
file_path = '/content/drive/MyDrive/Colab Notebooks/dataset/Sport_car_price.csv'

# Read the CSV file into a pandas DataFrame
car = pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Inspecting a DataFrame
#
# 2. .**head**() returns the first few rows (the “head” of the DataFrame).

# %%
# Display the first few rows of the dataframe
# Print the head of the sport_car_price data
car.head(10)
# Out:
#         Car Make             Car Model  Year Engine Size (L) Horsepower  \
# 0        Porsche                   911  2022               3        379
# 1    Lamborghini               Huracan  2021             5.2        630
# 2        Ferrari               488 GTB  2022             3.9        661
# 3           Audi                    R8  2022             5.2        562
# 4        McLaren                  720S  2021               4        710
# 5            BMW                    M8  2022             4.4        617
# 6  Mercedes-Benz                AMG GT  2021               4        523
# 7      Chevrolet              Corvette  2021             6.2        490
# 8           Ford  Mustang Shelby GT500  2022             5.2        760
# 9         Nissan            GT-R Nismo  2021             3.8        600
#
#   Torque (lb-ft) 0-60 MPH Time (seconds) Price (in USD)
# 0            331                       4        101,200
# 1            443                     2.8        274,390
# 2            561                       3        333,750
# 3            406                     3.2        142,700
# 4            568                     2.7        298,000
# 5            553                     3.1        130,000
# 6            494                     3.8        118,500
# 7            465                     2.8         59,900
# 8            625                     3.5         81,000
# 9            481                     2.5        212,000

# %% [markdown]
# 3. .**info**() shows information on each of the columns, such as the data type and number of missing values.

# %%
# Display the first few rows of the dataframe
# Print information about `sport_car_price`
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Car Make                 1007 non-null   object
#  1   Car Model                1007 non-null   object
#  2   Year                     1007 non-null   int64
#  3   Engine Size (L)          997 non-null    object
#  4   Horsepower               1007 non-null   object
#  5   Torque (lb-ft)           1004 non-null   object
#  6   0-60 MPH Time (seconds)  1007 non-null   object
#  7   Price (in USD)           1007 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 63.1+ KB

# %% [markdown]
# 4. .**shape** returns the number of rows and columns of the DataFrame.

# %%
# Print the shape of sport_car_price
car.shape
# Out:
# (1007, 8)

# %% [markdown]
# 5. .**describe**() calculates a few summary statistics for each column.

# %%
car.describe()
# Out:
#               Year
# count  1007.000000
# mean   2021.201589
# std       2.019802
# min    1965.000000
# 25%    2021.000000
# 50%    2021.000000
# 75%    2022.000000
# max    2023.000000

# %%
try:
    car['Price (in USD)'] = car['Price (in USD)'].str.replace(',', '').astype(int)
except Exception as e:
    print(f"An error occurred: {e}")
pd.options.display.float_format = '{:,.0f}'.format
car['Price (in USD)'].describe()
# Out:
# count       1,007
# mean      382,036
# std       738,323
# min        25,000
# 25%        71,800
# 50%       140,000
# 75%       250,000
# max     5,200,000
# Name: Price (in USD), dtype: float64

# %% [markdown]
# 6. Parts of a DataFrame
#
# *   .**values**: A two-dimensional NumPy array of values.
# *   .**columns**: An index of columns: the column names.
# *   .**index**: An index for the rows: either row numbers or row names.

# %%
# Print the values of sport_car_price
print(car.values,"\n")

# Print the column index of sport_car_price
print(car.columns,"\n")

# Print the row index of sport_car_price
print(car.index)
# Out:
# [['Porsche' '911' 2022 ... '331' '4' 101200]
#  ['Lamborghini' 'Huracan' 2021 ... '443' '2.8' 274390]
#  ['Ferrari' '488 GTB' 2022 ... '561' '3' 333750]
#  ...
#  ['McLaren' 'Senna' 2021 ... '590' '2.7' 1000000]
#  ['Pagani' 'Huayra' 2021 ... '738' '3' 2600000]
#  ['Rimac' 'Nevera' 2021 ... '1696' '1.85' 2400000]]
#
# Index(['Car Make', 'Car Model', 'Year', 'Engine Size (L)', 'Horsepower',
#        'Torque (lb-ft)', '0-60 MPH Time (seconds)', 'Price (in USD)'],
#       dtype='object')
#
# RangeIndex(start=0, stop=1007, step=1)

# %% [markdown]
# 7. Sorting rows : use .**sort_values**()

# %%
# Convert 'Price (in USD)' to numeric, removing commas
try:
    car['Price (in USD)'] = car['Price (in USD)'].str.replace(',', '').astype(int)
except Exception as e:
    print(f"An error occurred: {e}")

# Sort sport_car_price by individuals
sport_car_price_size = car.sort_values("Price (in USD)")

# Print the top few rows
sport_car_price_size.head(10)
# Out:
# An error occurred: Can only use .str accessor with string values!
#       Car Make   Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 886  Chevrolet      Camaro  2022             6.2        455            455
# 597  Chevrolet      Camaro  2021             6.2        455            455
# 997  Chevrolet      Camaro  2021             6.2        455            455
# 924  Chevrolet      Camaro  2021             6.2        455            455
# 92       Mazda  MX-5 Miata  2021               2        181            151
# 998       Ford     Mustang  2021             2.3        310            350
# 707      Dodge  Challenger  2022             3.6        305            268
# 317     Nissan        370Z  2021             3.7        332            270
# 895     Nissan        370Z  2021             3.7        332            270
# 879     Nissan        370Z  2021             3.7        332            270
#
#     0-60 MPH Time (seconds)  Price (in USD)
# 886                       4           25000
# 597                       4           25000
# 997                       4           25000
# 924                       4           25000
# 92                      6.5           26830
# 998                     5.3           27205
# 707                     6.4           28000
# 317                       5           30000
# 895                     5.2           30000
# 879                       5           30090

# %% [markdown]
# 8. Sorting rows : use .**sort_values**() : define ascending

# %%
# Sort sport_car_price by 'Price (in USD)'
sport_car_price_size = car.sort_values("Price (in USD)", ascending=False)

# Print the top few rows
sport_car_price_size.head(10)
# Out:
#         Car Make                Car Model  Year Engine Size (L) Horsepower  \
# 823      Bugatti  Chiron Super Sport 300+  2021               8       1578
# 541      Bugatti  Chiron Super Sport 300+  2022               8       1578
# 983      Bugatti                   Chiron  2022               8       1500
# 438  Lamborghini                     Sián  2021             6.5        819
# 624      Bugatti         Chiron Pur Sport  2021               8       1500
# 279       Pagani       Huayra Roadster BC  2021               6        791
# 385       Pagani                   Huayra  2021               6        764
# 174     W Motors         Lykan Hypersport  2015             3.7        780
# 782      Bugatti                   Chiron  2021               8       1479
# 571      Bugatti                   Chiron  2021               8       1479
#
#     Torque (lb-ft) 0-60 MPH Time (seconds)  Price (in USD)
# 823           1180                     2.4         5200000
# 541           1180                     2.3         5200000
# 983           1180                     2.5         3900000
# 438            531                     2.8         3600000
# 624           1180                     2.3         3599000
# 279            774                     2.5         3500000
# 385            738                     2.8         3500000
# 174            708                     2.8         3400000
# 782           1180                     2.4         3000000
# 571           1180                     2.5         3000000

# %% [markdown]
# 9. Sorting rows : use .**sort_values**() : define two value to sort

# %%
# Sort sport_car_price by 'Car Make', then descending 'Price (in USD)'
sport_car_price_make_price = car.sort_values(["Car Make", "Price (in USD)"], ascending=[True, False])

# Print the top few rows
sport_car_price_make_price.head(50)
# Out:
#          Car Make            Car Model  Year Engine Size (L) Horsepower  \
# 82          Acura                  NSX  2022             3.5        573
# 324         Acura                  NSX  2021             3.5        573
# 496         Acura                  NSX  2021             3.5        573
# 155         Acura                  NSX  2021             3.5        573
# 233         Acura                  NSX  2022             3.5        573
# 281         Acura                  NSX  2022             3.5        573
# 338         Acura                  NSX  2022             3.5        573
# 355         Acura                  NSX  2022             3.5        573
# 391         Acura                  NSX  2021             3.5        573
# 516         Acura                  NSX  2021             3.5        573
# 538         Acura                  NSX  2022             3.5        573
# 575         Acura                  NSX  2021             3.5        573
# 627         Acura                  NSX  2021             3.5        573
# 806         Acura                  NSX  2021             3.5        573
# 861         Acura                  NSX  2021             3.5        573
# 884         Acura                  NSX  2022             3.5        573
# 828    Alfa Romeo  Giulia Quadrifoglio  2022             2.9        505
# 410    Alfa Romeo  Giulia Quadrifoglio  2022             2.9        505
# 470    Alfa Romeo  Giulia Quadrifoglio  2022             2.9        505
# 964    Alfa Romeo  Giulia Quadrifoglio  2021             2.9        505
# 19     Alfa Romeo  Giulia Quadrifoglio  2022             2.9        505
# 325    Alfa Romeo  Giulia Quadrifoglio  2021             2.9        505
# 290    Alfa Romeo  Giulia Quadrifoglio  2021             2.9        505
# 927    Alfa Romeo  Giulia Quadrifoglio  2021             2.9        505
# 657    Alfa Romeo  Giulia Quadrifoglio  2021             2.9        505
# 577    Alfa Romeo  Giulia Quadrifoglio  2021             2.9        505
# 819    Alfa Romeo            4C Spider  2020             1.7        237
# 536    Alfa Romeo            4C Spider  2020             1.8        237
# 236    Alfa Romeo                   4C  2020             1.7        237
# 478    Alfa Romeo            4C Spider  2020             1.7        237
# 705    Alfa Romeo                   4C  2020             1.8        237
# 901    Alfa Romeo            4C Spider  2020             1.7        237
# 365        Alpine                 A110  2021             1.8        288
# 20          Ariel                 Atom  2021               2        320
# 195  Aston Martin     DBS Superleggera  2022             5.2        715
# 838  Aston Martin     DBS Superleggera  2022             5.2        715
# 953  Aston Martin     DBS Superleggera  2022             5.2        715
# 497  Aston Martin     DBS Superleggera  2022             5.2        715
# 682  Aston Martin     DBS Superleggera  2021             5.2        715
# 469  Aston Martin     DBS Superleggera  2021             5.2        715
# 517  Aston Martin     DBS Superleggera  2022             5.2        715
# 301  Aston Martin     DBS Superleggera  2022             5.2        715
# 532  Aston Martin     DBS Superleggera  2021             5.2        715
# 600  Aston Martin     DBS Superleggera  2021             5.2        715
# 618  Aston Martin     DBS Superleggera  2021             5.2        715
# 656  Aston Martin     DBS Superleggera  2021             5.2        715
# 112  Aston Martin     DBS Superleggera  2021             5.2        715
# 123  Aston Martin     DBS Superleggera  2021             5.2        715
# 264  Aston Martin     DBS Superleggera  2021             5.2        715
# 572  Aston Martin     DBS Superleggera  2021             5.2        715
#
#     Torque (lb-ft) 0-60 MPH Time (seconds)  Price (in USD)
# 82             476                     2.9          159495
# 324            476                     2.7          159495
# 496            476                     2.7          159495
# 155            476                     2.7          157500
# 233            476                     2.7          157500
# 281            476                     2.9          157500
# 338            476                     2.7          157500
# 355            476                     2.7          157500
# 391            476                     2.7          157500
# 516            476                     2.9          157500
# 538            476                     2.7          157500
# 575            476                     2.7          157500
# 627            476                     2.7          157500
# 806            476                     2.9          157500
# 861            476                     2.7          157500
# 884            476                     2.7          157500
# 828            443                     3.8           83250
# 410            443                     3.8           81250
# 470            443                     3.8           80500
# 964            443                     3.8           78450
# 19             443                     3.8           78000
# 325            443                     3.8           76950
# 290            443                     3.8           76400
# 927            443                     3.8           75250
# 657            443                     3.8           75000
# 577            443                     3.8           74750
# 819            258                     4.1           69000
# 536            258                     4.1           68745
# 236            258                     4.1           67150
# 478            258                     4.1           67150
# 705            258                     4.2           67150
# 901            258                     4.1           67150
# 365            236                     4.4           71500
# 20             243                     2.8           75000
# 195            663                     3.4          330000
# 838            664                     3.2          329100
# 953            663                     3.4          321000
# 497            664                     3.4          314500
# 682            663                     3.2          310000
# 469            663                     3.2          308000
# 517            663                     3.2          308000
# 301            664                     3.2          307820
# 532            664                     3.4          307820
# 600            664                     3.4          307820
# 618            664                     3.2          307820
# 656            663                     3.2          305000
# 112            664                     3.4          304995
# 123            664                     3.2          304995
# 264            663                     3.2          304995
# 572            664                     3.4          304995

# %% [markdown]
# 10. Subsetting columns

# %%
# Select the 'Car Make' and 'Price (in USD)' columns
make_price = car[["Car Make", "Price (in USD)"]]

# Print the head of the result
make_price.head(10)
# Out:
#         Car Make  Price (in USD)
# 0        Porsche          101200
# 1    Lamborghini          274390
# 2        Ferrari          333750
# 3           Audi          142700
# 4        McLaren          298000
# 5            BMW          130000
# 6  Mercedes-Benz          118500
# 7      Chevrolet           59900
# 8           Ford           81000
# 9         Nissan          212000

# %% [markdown]
# 11. Example of subsetting rows

# %%
# Filter for rows where Price (in USD) is greater than 3000000
price_gt_3000k = car[car["Price (in USD)"] > 3000000]

price_gt_3000k_sorted = price_gt_3000k.sort_values(by="Price (in USD)")

# See the result
price_gt_3000k_sorted.head(10)
# Out:
#         Car Make                Car Model  Year Engine Size (L) Horsepower  \
# 174     W Motors         Lykan Hypersport  2015             3.7        780
# 279       Pagani       Huayra Roadster BC  2021               6        791
# 385       Pagani                   Huayra  2021               6        764
# 624      Bugatti         Chiron Pur Sport  2021               8       1500
# 438  Lamborghini                     Sián  2021             6.5        819
# 983      Bugatti                   Chiron  2022               8       1500
# 541      Bugatti  Chiron Super Sport 300+  2022               8       1578
# 823      Bugatti  Chiron Super Sport 300+  2021               8       1578
#
#     Torque (lb-ft) 0-60 MPH Time (seconds)  Price (in USD)
# 174            708                     2.8         3400000
# 279            774                     2.5         3500000
# 385            738                     2.8         3500000
# 624           1180                     2.3         3599000
# 438            531                     2.8         3600000
# 983           1180                     2.5         3900000
# 541           1180                     2.3         5200000
# 823           1180                     2.4         5200000

# %% [markdown]
# 12. Example of subsetting rows

# %%
# Filter for rows where 'Car Make' is 'Audi'
audi_make = car[car["Car Make"] == "Audi"]

audi_make_sorted = audi_make.sort_values(by="Price (in USD)", ascending=False)

# See the result
audi_make_sorted.head(10)
# Out:
#     Car Make      Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 225     Audi      R8 Spyder  2022             5.2        562            406
# 3       Audi             R8  2022             5.2        562            406
# 974     Audi             R8  2022             5.2        562            406
# 856     Audi            RS6  2022               4        591            590
# 611     Audi           RS 7  2022               4        591            590
# 792     Audi            RS7  2022               4        591            590
# 30      Audi            RS7  2022               4        591            590
# 709     Audi            RS7  2022               4        591            590
# 411     Audi  RS7 Sportback  2022               4        591            590
# 215     Audi            RS7  2022               4        591            590
#
#     0-60 MPH Time (seconds)  Price (in USD)
# 225                     3.5          183300
# 3                       3.2          142700
# 974                     3.2          142700
# 856                     3.5          120000
# 611                     3.5          117000
# 792                     3.5          117000
# 30                      3.5          117000
# 709                     3.5          115045
# 411                     3.5          115045
# 215                     3.5          115045

# %% [markdown]
# 13. Example of subsetting rows

# %%
# Filter for rows where 'Price (in USD)' is more than 120000
# and 'Car Make' is 'Audi'
price_120k_make = car[(car["Price (in USD)"] > 120000) & (car["Car Make"] == "Audi")]

price_120k_make
# Out:
#     Car Make  Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 3       Audi         R8  2022             5.2        562            406
# 225     Audi  R8 Spyder  2022             5.2        562            406
# 974     Audi         R8  2022             5.2        562            406
#
#     0-60 MPH Time (seconds)  Price (in USD)
# 3                       3.2          142700
# 225                     3.5          183300
# 974                     3.2          142700

# %% [markdown]
# 14. Example of subsetting rows

# %%
# Subset for rows in 'Audi' or 'BMW' car make
audi_bmw = car[(car["Car Make"] == "Audi") | (car["Car Make"] == "BMW")]

# See the result
audi_bmw
# Out:
#     Car Make Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 3       Audi        R8  2022             5.2        562            406
# 5        BMW        M8  2022             4.4        617            553
# 30      Audi       RS7  2022               4        591            590
# 32       BMW        M4  2022               3        503            479
# 40      Audi       RS3  2022             2.5        394            369
# ..       ...       ...   ...             ...        ...            ...
# 960      BMW        M4  2022               3        473            406
# 974     Audi        R8  2022             5.2        562            406
# 976      BMW        M8  2022             4.4        617            553
# 993     Audi      RS 5  2021             2.9        444            443
# 995      BMW        M2  2021               3        405            406
#
#     0-60 MPH Time (seconds)  Price (in USD)
# 3                       3.2          142700
# 5                       3.1          130000
# 30                      3.5          117000
# 32                      3.8           72800
# 40                      3.9           57000
# ..                      ...             ...
# 960                     4.1           72800
# 974                     3.2          142700
# 976                     3.1          130000
# 993                     3.5           75100
# 995                       4           58900
#
# [134 rows x 8 columns]

# %% [markdown]
# 15. Example of subsetting rows : use isin()

# %%
# The Car Make
car_m = ["Audi", "BMW", "Ford", "Porsche"]

# Filter for rows in the Car Make
car_m_sport_car_price = car[car["Car Make"].isin(car_m)]

# See the result
car_m_sport_car_price
# Out:
#     Car Make             Car Model  Year Engine Size (L) Horsepower  \
# 0    Porsche                   911  2022               3        379
# 3       Audi                    R8  2022             5.2        562
# 5        BMW                    M8  2022             4.4        617
# 8       Ford  Mustang Shelby GT500  2022             5.2        760
# 18   Porsche               Boxster  2021               2        300
# ..       ...                   ...   ...             ...        ...
# 979     Ford  Mustang Shelby GT500  2022             5.2        760
# 990  Porsche                Cayman  2021               2        300
# 993     Audi                  RS 5  2021             2.9        444
# 995      BMW                    M2  2021               3        405
# 998     Ford               Mustang  2021             2.3        310
#
#     Torque (lb-ft) 0-60 MPH Time (seconds)  Price (in USD)
# 0              331                       4          101200
# 3              406                     3.2          142700
# 5              553                     3.1          130000
# 8              625                     3.5           81000
# 18             280                     4.7           62000
# ..             ...                     ...             ...
# 979            625                     3.5           81000
# 990            280                     5.1           59900
# 993            443                     3.5           75100
# 995            406                       4           58900
# 998            350                     5.3           27205
#
# [270 rows x 8 columns]

# %% [markdown]
# 16. Adding new columns

# %%
# Add interest col (1.79%)
car["Interest 1.79%"] =  car["Price (in USD)"] * 1.79  / 100

# Add total col (Price (in USD)+Interest 1.79%)
car["Total price (in USD)"] =  car["Price (in USD)"] + car["Interest 1.79%"]

# See the result
car
# Out:
#          Car Make Car Model  Year Engine Size (L) Horsepower Torque (lb-ft)  \
# 0         Porsche       911  2022               3        379            331
# 1     Lamborghini   Huracan  2021             5.2        630            443
# 2         Ferrari   488 GTB  2022             3.9        661            561
# 3            Audi        R8  2022             5.2        562            406
# 4         McLaren      720S  2021               4        710            568
# ...           ...       ...   ...             ...        ...            ...
# 1002   Koenigsegg     Jesko  2022               5       1280           1106
# 1003        Lotus     Evija  2021  Electric Motor       1972           1254
# 1004      McLaren     Senna  2021               4        789            590
# 1005       Pagani    Huayra  2021               6        764            738
# 1006        Rimac    Nevera  2021  Electric Motor       1888           1696
#
#      0-60 MPH Time (seconds)  Price (in USD)  Interest 1.79%  \
# 0                          4          101200           1,811
# 1                        2.8          274390           4,912
# 2                          3          333750           5,974
# 3                        3.2          142700           2,554
# 4                        2.7          298000           5,334
# ...                      ...             ...             ...
# 1002                     2.5         3000000          53,700
# 1003                       2         2000000          35,800
# 1004                     2.7         1000000          17,900
# 1005                       3         2600000          46,540
# 1006                    1.85         2400000          42,960
#
#       Total price (in USD)
# 0                  103,011
# 1                  279,302
# 2                  339,724
# 3                  145,254
# 4                  303,334
# ...                    ...
# 1002             3,053,700
# 1003             2,035,800
# 1004             1,017,900
# 1005             2,646,540
# 1006             2,442,960
#
# [1007 rows x 10 columns]

# %% [markdown]
# 16. **Summary statistics**
# *   .**mean**()
# *   .**median**()
# *   .**max**()
# *   .**min**()

# %%
print(car["Price (in USD)"].mean())
print(car["Price (in USD)"].median())
print(car["Price (in USD)"].max())
print(car["Price (in USD)"].min())
# Out:
# 382035.9414101291
# 140000.0
# 5200000
# 25000

# %% [markdown]
# 18.   .**agg**(): to apply one or more aggregation functions to one or more columns of a DataFrame.

# %%
# Aggregating the mean and max of the "Price (in USD)" column
agg_price = car["Price (in USD)"].agg(["min", "max"])
print(agg_price)

# Custom function to find the range (max - min)
def range_func(x):
    return x.max() - x.min()

# Aggregating with a custom function
agg_custom = car["Price (in USD)"].agg(["median", "mean", range_func])
agg_custom
# Out:
# min      25000
# max    5200000
# Name: Price (in USD), dtype: int64
# median         140,000
# mean           382,036
# range_func   5,175,000
# Name: Price (in USD), dtype: float64

# %% [markdown]
# # แบบฝึกหัด
# 1. จงสร้าง subset  ชื่อ subset_year  เพื่อแสดงข้อมูลรถที่ผลิตในปี 2022 เท่านั้น

# %%
#เขียน code ตรงนี้

# %%
#ตัวอย่างผลลัพธ์
# Out:
# Subset where Year = 2022:
#          Car Make             Car Model  Year  Engine Size (L)  Horsepower  \
# 0        Porsche                   911  2022                3         379
# 2        Ferrari               488 GTB  2022                4         661
# 3           Audi                    R8  2022                5         562
# 5            BMW                    M8  2022                4         617
# 8           Ford  Mustang Shelby GT500  2022                5         760
# ...          ...                   ...   ...              ...         ...
# 984   Koenigsegg                 Jesko  2022                5       1,280
# 986        Rimac                Nevera  2022              NaN       1,914
# 987        Lotus                 Evija  2022              NaN       1,973
# 994      McLaren                    GT  2022                4         612
# 1002  Koenigsegg                 Jesko  2022                5       1,280
#
#       Torque (lb-ft)  0-60 MPH Time (seconds)  Price (in USD)  Interest 1.79%  \
# 0                331                        4          101200           1,811
# 2                561                        3          333750           5,974
# 3                406                        3          142700           2,554
# 5                553                        3          130000           2,327
# 8                625                        4           81000           1,450
# ...              ...                      ...             ...             ...
# 984            1,015                        2         3000000          53,700
# 986            1,696                        2         2400000          42,960
# 987            1,254                        2         2000000          35,800
# 994              465                        3          210000           3,759
# 1002           1,106                        2         3000000          53,700
#
#       Total price (in USD)
# 0                  103,011
# 2                  339,724
# 3                  145,254
# 5                  132,327
# 8                   82,450
# ...                    ...
# 984              3,053,700
# 986              2,442,960
# 987              2,035,800
# 994                213,759
# 1002             3,053,700
#
# [382 rows x 10 columns]

# %% [markdown]
# 2. จงสร้าง subset_price  ที่นำ subset_year มากรองเฉพาะรถที่มีแรงม้ามากกว่า 400 และมีราคาต่ำกว่า 60000

# %%
#เขียน code ตรงนี้
# 2. Subset rows where Horsepower > 400 and Price (in USD) < 60000

# %%
#ตัวอย่าง output
# Out:
# Subset where Horsepower > 400 and Price (in USD) < 60000:
#        Car Make              Car Model  Year  Engine Size (L)  Horsepower  \
# 52        Ford             Mustang GT  2022                5         460
# 64         BMW                     M2  2022                3         405
# 120        BMW                     M2  2022                3         405
# 128        BMW                     M2  2022                3         405
# 144  Chevrolet              Camaro SS  2022                6         455
# 150       Audi                   RS 3  2022                2         401
# 188       Audi                   RS 3  2022                2         401
# 217        BMW         M2 Competition  2022                3         405
# 253        BMW                     M2  2022                3         405
# 268        BMW         M2 Competition  2022                3         405
# 403        BMW         M2 Competition  2022                3         405
# 413  Chevrolet              Camaro SS  2022                6         455
# 447  Chevrolet              Camaro SS  2022                6         455
# 448       Ford             Mustang GT  2022                5         460
# 463        BMW                     M2  2022                3         405
# 595        BMW                     M2  2022                3         405
# 650        BMW                     M2  2022                3         405
# 663       Ford             Mustang GT  2022                5         460
# 679        BMW                     M2  2022                3         405
# 740  Chevrolet              Camaro SS  2022                6         455
# 777  Chevrolet  Camaro SS Convertible  2022                6         455
# 812        BMW         M2 Competition  2022                3         405
# 815       Ford             Mustang GT  2022                5         460
# 848        BMW                     M2  2022                3         405
# 886  Chevrolet                 Camaro  2022                6         455
# 903        BMW                     M2  2022                3         405
# 922        BMW                     M2  2022                3         405
# 939  Chevrolet              Camaro SS  2022                6         455
# 940       Ford             Mustang GT  2022                5         460
#
#      Torque (lb-ft)  0-60 MPH Time (seconds)  Price (in USD)  Interest 1.79%  \
# 52              420                        4           39000             698
# 64              406                        4           58900           1,054
# 120             406                        4           59000           1,056
# 128             406                        4           58900           1,054
# 144             455                        4           44000             788
# 150             369                        4           56200           1,006
# 188             354                        4           56000           1,002
# 217             406                        4           59895           1,072
# 253             406                        4           58900           1,054
# 268             406                        4           59895           1,072
# 403             406                        4           59895           1,072
# 413             455                        4           42000             752
# 447             455                        4           42500             761
# 448             420                        4           36120             647
# 463             406                        4           58900           1,054
# 595             406                        4           58900           1,054
# 650             406                        4           58900           1,054
# 663             420                        4           45000             806
# 679             406                        4           58900           1,054
# 740             455                        4           43995             788
# 777             455                        4           49000             877
# 812             406                        4           58900           1,054
# 815             420                        4           43000             770
# 848             406                        4           58900           1,054
# 886             455                        4           25000             448
# 903             406                        4           58900           1,054
# 922             406                        4           58900           1,054
# 939             455                        4           37500             671
# 940             420                        4           38500             689
#
#      Total price (in USD)
# 52                 39,698
# 64                 59,954
# 120                60,056
# 128                59,954
# 144                44,788
# 150                57,206
# 188                57,002
# 217                60,967
# 253                59,954
# 268                60,967
# 403                60,967
# 413                42,752
# 447                43,261
# 448                36,767
# 463                59,954
# 595                59,954
# 650                59,954
# 663                45,806
# 679                59,954
# 740                44,783
# 777                49,877
# 812                59,954
# 815                43,770
# 848                59,954
# 886                25,448
# 903                59,954
# 922                59,954
# 939                38,171
# 940                39,189
# (29, 10)

# %% [markdown]
# 3. จาก subset_price ให้สร้าง subset_brand เพื่อกรองเฉพาะข้อมูลรถยี่ห้อฟอร์ด และแสดงเฉพาะ 4 แอททริบิวต์ตามตัวอย่าง

# %%
#เขียน code ตรงนี้

# %%
# ตัวอย่างผลลัพธ์
# Out:
# Subset for 'Ford' cars with specific columns:
#      Car Make   Car Model  Year  Horsepower
# 52      Ford  Mustang GT  2022         460
# 448     Ford  Mustang GT  2022         460
# 663     Ford  Mustang GT  2022         460
# 815     Ford  Mustang GT  2022         460
# 940     Ford  Mustang GT  2022         460
